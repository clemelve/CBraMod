# %% [markdown]
# ### Notebook 1
#
# This notebook repoduces the experiments of the paper on the SHU-MI dataset. " SHU-MI is an EEG motor imagery dataset with two categories (left hand and right hand). It consists of 32-channel EEG signals with 250 Hz sampling rate, collected from 25 subjects. The EEG signals are segmented into 11,988 samples and resampled to 200 Hz. "
#
# The fine-tuning function is already implemented in the repository, the default parameters being the one reported in the paper.

# %%
# %run finetune_main.py \
    --downstream_dataset SHU-MI \
    --datasets_dir custom_shu/ \
    --num_of_classes 2 \
    --model_dir checkpoints \
    --epochs 50
# Out:
# Namespace(seed=3407, cuda=0, epochs=50, batch_size=64, lr=0.0001, weight_decay=0.05, optimizer='AdamW', clip_value=1, dropout=0.1, classifier='all_patch_reps', downstream_dataset='SHU-MI', datasets_dir='custom_shu/', num_of_classes=2, model_dir='checkpoints', num_workers=16, label_smoothing=0.1, multi_lr=True, frozen=False, use_pretrained_weights=True, foundation_dir='pretrained_weights/pretrained_weights.pth')
# The downstream dataset is SHU-MI
# 7210 2431 2347
# 11988
# Model(
#   (backbone): CBraMod(
#     (patch_embedding): PatchEmbedding(
#       (positional_encoding): Sequential(
#         (0): Conv2d(200, 200, kernel_size=(19, 7), stride=(1, 1), padding=(9, 3), groups=200)
#       )
#       (proj_in): Sequential(
#         (0): Conv2d(1, 25, kernel_size=(1, 49), stride=(1, 25), padding=(0, 24))
#         (1): GroupNorm(5, 25, eps=1e-05, affine=True)
#         (2): GELU(approximate='none')
#         (3): Conv2d(25, 25, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1))
# ...

# %% [markdown]
# ## Brief note :
#
# Last model save happens at epoch 5, which is a clear sign of overfitting on the training dataset, it memorizes the training set rather than generalizing across subjects.
#
# The metric results on the test set, with seed 3407, are : acc: 0.61498, pr_auc: 0.70104, roc_auc: 0.68130.
#
# While in the paper, it is reported : acc: 0.6370 ± 0.0151, pr_auc: 0.7139 ± 0.0088, roc_auc: 0.6988 ± 0.0068.
#
# So the results are clearly lower than expected.
